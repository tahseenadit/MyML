# %% [markdown]
# # The Hello World of Deep Learning with Neural Networks

# %% [markdown]
# A neural network is just a slightly more advanced implementation of machine learning and we call that deep learning. A neural network is basically a set of functions which can learn patterns.

# %% [markdown]
# In normal programming, we give the data and rules and expect the answer to be returned by the programme. So, for example, if you were writing code for a function like this, you already know the 'rules' —
#
#
# ```
# float hw_function(float x){ // The argument passed to the parameter is the data
#     float y = (2 * x) - 1; // This is the rule
#     return y; // this is the answer that is goint to be returned
# }
# ```
#
# So how would you train a neural network to do the equivalent task? Using data! By feeding it with a set of Xs, and a set of Ys, it should be able to figure out the relationship between them. So, in neural network, we give the data and the answer and hope that the neural network will return the rule.
#
# This is obviously a very different paradigm than what you might be used to, so let's step through it piece by piece.

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %% [markdown]
# ## Define and Compile the Neural Network
#
# Next we will create the simplest possible neural network. It has 1 layer which is dense. Dense meanse that the neurons in that layer are connected. In our neural network, that layer has only 1 neuron which is indicated by the 'units' parameter, and the input shape to that single neuron is just 1 value.

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %% [markdown]
# There's only one dense here. So there's only one layer and there's only one unit in it, so it's a single neuron. Successive layers are defined in sequence, hence the word sequential. It takes a list of layers. Like, 'tf.keras.Sequential([ ])'. But as I've said, there's only one. So you have a single neuron. You define the shape of what's input to the neural network in the first and in this case the only layer, and you can see that our input shape is super simple. It's just one value.

# %% [markdown]
# Now we compile our Neural Network. When we do so, we have to specify 2 functions, a loss and an optimizer.
#
# We know that in our function, the relationship between the numbers is y=2x-1.
#
# When the computer is trying to 'learn' that, it makes a guess...maybe y=10x+10. Remember that we know the answer but we do not know the rule to create those answers, that is the job of our neural network. The LOSS function measures the guessed answers against the known correct answers and measures how well or how badly it did.
#
# It then uses the OPTIMIZER function to make another guess. So, basically the LOSS function tells the OPTIMIZER - 'Hey, optimizer! I have found that the previous guess was a good guess or a bad guess, I will tell you how much good or bad that guess was and based on that measurement, please make another guess and let me know that guess.' Based on how the loss function went, the optimizer will try to make another guess to minimize the loss by making the guess better than the previous guess. At that point maybe it will come up with somehting like y=5x+5, which, while still pretty bad, is closer to the correct result (i.e. the loss is lower)
#
# It will repeat this for the number of EPOCHS which you will see shortly. But first, here's how we tell it to use 'MEAN SQUARED ERROR' for the loss and 'STOCHASTIC GRADIENT DESCENT' for the optimizer. You don't need to understand the math for these yet, but you can see that they work! :)
#
# Over time you will learn the different and appropriate loss and optimizer functions for different scenarios.

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %% [markdown]
# ## Providing the Data
#
# Next up we'll feed in some data. In this case we are taking 6 xs and 6ys. You can see that the relationship between these is that y=2x-1, so where x = -1, y=-3 etc. etc.
#
# A python library called 'Numpy' provides lots of array type data structures that are a defacto standard way of doing it. We declare that we want to use these by specifying the values as an np.array[]

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %% [markdown]
# # Training the Neural Network

# %% [markdown]
# The process of training the neural network, where it 'learns' the relationship between the Xs and Ys is in the **model.fit**  call. This is where it will go through the loop we spoke about above, making a guess, measuring how good or bad it is (aka the loss), using the opimizer to make another guess etc. It will do it for the number of epochs you specify. When you run this code, you'll see the loss on the right hand side.

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 1ms/step - loss: 58.9608
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 46.8149
# Epoch 3/500
# 1/1 [==============================] - 0s 1ms/step - loss: 37.2503
# Epoch 4/500
# 1/1 [==============================] - 0s 4ms/step - loss: 29.7168
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 23.7813
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 19.1034
# Epoch 7/500
# 1/1 [==============================] - 0s 1ms/step - loss: 15.4149
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 12.5050
# Epoch 9/500
# 1/1 [==============================] - 0s 1ms/step - loss: 10.2080
# Epoch 10/500
# 1/1 [==============================] - 0s 2ms/step - loss: 8.3932
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 6.9579
# Epoch 12/500
# 1/1 [==============================] - 0s 2ms/step - loss: 5.8215
# ...

# %% [markdown]
# Ok, now you have a model that has been trained to learn the relationship between X and Y. You can use the **model.predict** method to have it figure out the Y for a previously unknown X. So, for example, if X = 10, what do you think Y will be? Take a guess before you run this code:

# %%
print(model.predict([10.0]))
# Out:
# [[18.975504]]

# %% [markdown]
# You might have thought 19, right? But it ended up being a little under. Why do you think that is?
#
# Remember that neural networks deal with probabilities, so given the data that we fed the NN with, it calculated that there is a very high probability that the relationship between X and Y is Y=2X-1, but with only 6 data points we can't know for sure. As a result, the result for 10 is very close to 19, but not necessarily 19.
